# %%
import gdal
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %matplotlib inline

# %% [markdown]
# Specify the MxD03 Geolocation file we want to look at

# %%
filepath = r'C:\Users\steve\OneDrive\Documents\School Stuff\UW\Mountain Hydrology Research Group\MODIS\Tuolumne_2017_MxD03\MOD03.A2017109.0520.061.2017314020111.hdf'

# %% [markdown]
# Open the file with GDAL

# %%
a = gdal.Open(filepath)

# %% [markdown]
# Inspect the file to see its SDSs

# %%
a.GetSubDatasets()
# Out:
# [('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:Scan Offset',
#   '[4060x2708] Scan Offset MODIS_Swath_Type_GEO (8-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:Track Offset',
#   '[4060x2708] Track Offset MODIS_Swath_Type_GEO (8-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:Height Offset',
#   '[4060x2708] Height Offset MODIS_Swath_Type_GEO (8-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:Height',
#   '[2030x1354] Height MODIS_Swath_Type_GEO (16-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:SensorZenith',
#   '[2030x1354] SensorZenith MODIS_Swath_Type_GEO (16-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:SensorAzimuth',
#   '[2030x1354] SensorAzimuth MODIS_Swath_Type_GEO (16-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:Range',
#   '[2030x1354] Range MODIS_Swath_Type_GEO (16-bit unsigned integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:SolarZenith',
#   '[2030x1354] SolarZenith MODIS_Swath_Type_GEO (16-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:SolarAzimuth',
#   '[2030x1354] SolarAzimuth MODIS_Swath_Type_GEO (16-bit integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:Land/SeaMask',
#   '[2030x1354] Land/SeaMask MODIS_Swath_Type_GEO (8-bit unsigned integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:WaterPresent',
#   '[2030x1354] WaterPresent MODIS_Swath_Type_GEO (8-bit unsigned integer)'),
#  ('HDF4_EOS:EOS_SWATH:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":MODIS_Swath_Type_GEO:gflags',
#   '[2030x1354] gflags MODIS_Swath_Type_GEO (8-bit unsigned integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":0',
#   '[2030x1354] Latitude (32-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":1',
#   '[2030x1354] Longitude (32-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":2',
#   '[4060x2708] Scan Offset (8-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":3',
#   '[4060x2708] Track Offset (8-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":4',
#   '[4060x2708] Height Offset (8-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":5',
#   '[2030x1354] Height (16-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":6',
#   '[2030x1354] SensorZenith (16-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":7',
#   '[2030x1354] SensorAzimuth (16-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":8',
#   '[2030x1354] Range (16-bit unsigned integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":9',
#   '[2030x1354] SolarZenith (16-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":10',
#   '[2030x1354] SolarAzimuth (16-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":11',
#   '[2030x1354] Land/SeaMask (8-bit unsigned integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":12',
#   '[2030x1354] WaterPresent (8-bit unsigned integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":13',
#   '[2030x1354] gflags (8-bit unsigned integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":25',
#   '[203x3] Moon Vector (32-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":26',
#   '[203x4] L1 scan quality (32-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":27',
#   '[203x4] Geo scan quality (8-bit integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":28',
#   '[203x3] orb_pos (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":29',
#   '[203x3] orb_vel (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":30',
#   '[203x3x3] T_inst2ECR (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":31',
#   '[203x3] attitude_angles (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":32',
#   '[203x3] sun_ref (32-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":34',
#   '[203x25] impulse_enc (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":35',
#   '[203x25] impulse_time (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":36',
#   '[203x10] Scan Type (8-bit character)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":37',
#   '[203x3] thermal_correction (32-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":38',
#   '[203x1354] attitude_quality (32-bit unsigned integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":39',
#   '[203x1354] ephemeris_quality (32-bit unsigned integer)'),
#  ('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":43',
#   '[37x2] detector_offsets (64-bit floating-point)')]

# %% [markdown]
# Load the longitude, latitude, and height SDSs with GDAL

# %%
latitude = gdal.Open('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":0')
longitude = gdal.Open('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":1')
height = gdal.Open('HDF4_SDS:UNKNOWN:"C:\\Users\\steve\\OneDrive\\Documents\\School Stuff\\UW\\Mountain Hydrology Research Group\\MODIS\\Tuolumne_2017_MxD03\\MOD03.A2017109.0520.061.2017314020111.hdf":5')

# %% [markdown]
# Read each SDS as an array

# %%
latitude = latitude.ReadAsArray()
longitude = longitude.ReadAsArray()
height = height.ReadAsArray()

# %% [markdown]
# Plot both latitude and longitudes, and the height map

# %%
fig, ax = plt.subplots(1,3,figsize=(21,7))

ax[0].imshow(latitude, interpolation='nearest')
ax[0].set_title('Latitude')

ax[1].imshow(longitude, interpolation='nearest')
ax[1].set_title('Longitude');

ax[2].imshow(height, interpolation='nearest')
ax[2].set_title('Height');

# %% [markdown]
# Plot the hight map projected correctly

# %%
plt.figure(figsize=(15,15))

img_extent = (-124, -115, 33, 40)

ax = plt.axes(extent=img_extent, projection=ccrs.PlateCarree())
ax.coastlines(resolution='10m', color='white', linewidth=1)

plt.pcolormesh(longitude, latitude, height, cmap=plt.cm.gist_earth, vmin=-1000, transform=ccrs.PlateCarree())

plt.show()

# %%
latitude.shape
# Out:
# (2030, 1354)
